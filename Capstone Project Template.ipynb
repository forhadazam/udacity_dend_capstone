# %% [markdown]
# # Project Title
# ### Data Engineering Capstone Project
#
# #### Project Summary
# --describe your project at a high level--
#
# The project follows the follow steps:
# * Step 1: Scope the Project and Gather Data
# * Step 2: Explore and Assess the Data
# * Step 3: Define the Data Model
# * Step 4: Run ETL to Model the Data
# * Step 5: Complete Project Write Up

# %%
# Do all imports and installs here
import pandas as pd
pd.options.display.max_columns = None

# %% [markdown]
# ### Step 1: Scope the Project and Gather Data
#
# #### Scope
# Explain what you plan to do in the project in more detail. What data do you use? What is your end solution look like? What tools did you use? etc>
#
# #### Describe and Gather Data
# Describe the data sets you're using. Where did it come from? What type of information is included?

# %%
# %%time
# Read in the data here
file = "../../data/18-83510-I94-Data-2016/i94_jun16_sub.sas7bdat"
df = pd.read_sas(file, 'sas7bdat', encoding="ISO-8859-1")
# Out:
# CPU times: user 1min 44s, sys: 30.9 s, total: 2min 15s
# Wall time: 7min 43s

# %%
df.head()
# Out:
#    cicid   i94yr  i94mon  i94cit  i94res i94port  arrdate  i94mode i94addr  \
# 0    4.0  2016.0     6.0   135.0   135.0     XXX  20612.0      NaN     NaN
# 1    5.0  2016.0     6.0   135.0   135.0     XXX  20612.0      NaN     NaN
# 2    6.0  2016.0     6.0   213.0   213.0     XXX  20609.0      NaN     NaN
# 3    7.0  2016.0     6.0   213.0   213.0     XXX  20611.0      NaN     NaN
# 4   16.0  2016.0     6.0   245.0   245.0     XXX  20632.0      NaN     NaN
#
#    depdate  i94bir  i94visa  count  validres  delete_days  delete_mexl  \
# 0      NaN    59.0      2.0    1.0       1.0          0.0          0.0
# 1      NaN    50.0      2.0    1.0       1.0          0.0          0.0
# 2      NaN    27.0      3.0    1.0       1.0          0.0          0.0
# 3      NaN    23.0      3.0    1.0       1.0          0.0          0.0
# 4      NaN    24.0      3.0    1.0       1.0          0.0          0.0
#
#    delete_dup  delete_visa  delete_recdup dtadfile visapost occup entdepa  \
# 0         0.0          0.0            0.0      NaN      NaN   NaN       Z
# 1         0.0          0.0            0.0      NaN      NaN   NaN       Z
# 2         0.0          0.0            0.0      NaN      NaN   NaN       T
# 3         0.0          0.0            0.0      NaN      NaN   NaN       T
# 4         0.0          0.0            0.0      NaN      NaN   NaN       T
#
#   entdepd entdepu matflag  biryear   dtaddto gender insnum airline  \
# 0     NaN       U     NaN   1957.0  10032016    NaN    NaN     NaN
# 1     NaN       U     NaN   1966.0  10032016    NaN    NaN     NaN
# 2     NaN       U     NaN   1989.0       D/S    NaN    NaN     NaN
# 3     NaN       U     NaN   1993.0       D/S    NaN    NaN     NaN
# 4     NaN       U     NaN   1992.0       D/S    NaN    NaN     NaN
#
#          admnum fltno visatype
# 0  1.493846e+10   NaN       WT
# 1  1.746006e+10   NaN       WT
# 2  1.679298e+09   NaN       F1
# 3  1.140963e+09   NaN       F1
# 4  1.934535e+09   NaN       F1

# %%
df.dtypes
# Out:
# cicid            float64
# i94yr            float64
# i94mon           float64
# i94cit           float64
# i94res           float64
# i94port           object
# arrdate          float64
# i94mode          float64
# i94addr           object
# depdate          float64
# i94bir           float64
# i94visa          float64
# count            float64
# validres         float64
# delete_days      float64
# delete_mexl      float64
# delete_dup       float64
# delete_visa      float64
# delete_recdup    float64
# dtadfile          object
# visapost          object
# occup             object
# entdepa           object
# entdepd           object
# entdepu           object
# matflag           object
# biryear          float64
# dtaddto           object
# gender            object
# insnum            object
# airline           object
# admnum           float64
# fltno             object
# visatype          object
# dtype: object

# %%
20612/365+1970
# Out:
# 2026.4712328767123

# %%
demo_df = pd.read_csv("us-cities-demographics.csv",delimiter=';')
demo_df.head()
# Out:
#                City          State  Median Age  Male Population  \
# 0     Silver Spring       Maryland        33.8          40601.0
# 1            Quincy  Massachusetts        41.0          44129.0
# 2            Hoover        Alabama        38.5          38040.0
# 3  Rancho Cucamonga     California        34.5          88127.0
# 4            Newark     New Jersey        34.6         138040.0
#
#    Female Population  Total Population  Number of Veterans  Foreign-born  \
# 0            41862.0             82463              1562.0       30908.0
# 1            49500.0             93629              4147.0       32935.0
# 2            46799.0             84839              4819.0        8229.0
# 3            87105.0            175232              5821.0       33878.0
# 4           143873.0            281913              5829.0       86253.0
#
#    Average Household Size State Code                       Race  Count
# 0                    2.60         MD         Hispanic or Latino  25924
# 1                    2.39         MA                      White  58723
# 2                    2.58         AL                      Asian   4759
# 3                    3.18         CA  Black or African-American  24437
# 4                    2.73         NJ                      White  76402

# %%
demo_df.loc[demo_df['State'] == 'California',:].sort_values(by=['City','Race'])
# Out:
#               City       State  Median Age  Male Population  \
# 1046       Alameda  California        41.4          37747.0
# 2081       Alameda  California        41.4          37747.0
# 1819       Alameda  California        41.4          37747.0
# 1293       Alameda  California        41.4          37747.0
# 1294       Alameda  California        41.4          37747.0
# 407       Alhambra  California        41.0          42184.0
# 1086      Alhambra  California        41.0          42184.0
# 2865      Alhambra  California        41.0          42184.0
# 2864      Alhambra  California        41.0          42184.0
# 1263      Alhambra  California        41.0          42184.0
# 1366       Anaheim  California        33.6         179603.0
# 2533       Anaheim  California        33.6         179603.0
# 239        Anaheim  California        33.6         179603.0
# 124        Anaheim  California        33.6         179603.0
# 2804       Anaheim  California        33.6         179603.0
# 489        Antioch  California        34.0          54733.0
# 1820       Antioch  California        34.0          54733.0
# 1913       Antioch  California        34.0          54733.0
# 346        Antioch  California        34.0          54733.0
# 200        Antioch  California        34.0          54733.0
# 2145  Apple Valley  California        34.3          32873.0
# 1425  Apple Valley  California        34.3          32873.0
# 2590  Apple Valley  California        34.3          32873.0
# 1790  Apple Valley  California        34.3          32873.0
# 1699  Apple Valley  California        34.3          32873.0
# 2287  Arden-Arcade  California        41.5          47596.0
# 2005  Arden-Arcade  California        41.5          47596.0
# 912   Arden-Arcade  California        41.5          47596.0
# 1242  Arden-Arcade  California        41.5          47596.0
# 629   Arden-Arcade  California        41.5          47596.0
# ...            ...         ...         ...              ...
# 1153         Vista  California        29.3          50680.0
# 1739  Walnut Creek  California        47.6          31994.0
# 397   Walnut Creek  California        47.6          31994.0
# 1346  Walnut Creek  California        47.6          31994.0
# 1597  Walnut Creek  California        47.6          31994.0
# 807    West Covina  California        39.8          51629.0
# 7      West Covina  California        39.8          51629.0
# 1975   West Covina  California        39.8          51629.0
# 1668                    2.90         CA          Black or African-American
# 330                     2.90         CA                 Hispanic or Latino
# 2204                    2.90         CA                              White
#
#        Count
# 1046    1329
# 2081   27984
# 1819    7364
# 1293    8265
# 1294   44232
# 407      687
# 1086   44067
# 2865    1905
# 2864   31386
# 1263   20811
# 1366    2489
# 2533   53270
# 239     9775
# 124   201593
# 2804  259820
# 489     3462
# 1820   14333
# 1913   23227
# 346    35563
# 200    51151
# 2145    1446
# 1425    2281
# 2590    9124
# 1790   25928
# 1699   60767
# 2287    2587
# 2005    7355
# 912    13647
# 1242   15273
# 629    69369
# ...      ...
# 1153   83529
# 1739   10831
# 397     1705
# 1346    5212
# 1597   57064
# 807      518
# 7      32716
# 1975    3693
# 967    58907
# 1417   48046
# 759     1022
# 1288   46560
# 2289    2270
# 836    19111
# 250    37593
# 2040     680
# 1342    3503
# 1376    1262
# 1375   61249
# 2543   49388
# 589      211
# 990    17616
# 1669    1326
# 713    10599
# 989    49980
# 587     2163
# 1895   15065
# 1668    1912
# 330    20890
# 2204   48746
#
# [676 rows x 12 columns]

# %%
immi_df = pd.read_csv("immigration_data_sample.csv")
immi_df.head()
# Out:
#    Unnamed: 0      cicid   i94yr  i94mon  i94cit  i94res i94port  arrdate  \
# 0     2027561  4084316.0  2016.0     4.0   209.0   209.0     HHW  20566.0
# 1     2171295  4422636.0  2016.0     4.0   582.0   582.0     MCA  20567.0
# 2      589494  1195600.0  2016.0     4.0   148.0   112.0     OGG  20551.0
# 3     2631158  5291768.0  2016.0     4.0   297.0   297.0     LOS  20572.0
# 4     3032257   985523.0  2016.0     4.0   111.0   111.0     CHM  20550.0
#
#    i94mode i94addr  depdate  i94bir  i94visa  count  dtadfile visapost occup  \
# 0      1.0      HI  20573.0    61.0      2.0    1.0  20160422      NaN   NaN
# 1      1.0      TX  20568.0    26.0      2.0    1.0  20160423      MTR   NaN
# 2      1.0      FL  20571.0    76.0      2.0    1.0  20160407      NaN   NaN
# 3      1.0      CA  20581.0    25.0      2.0    1.0  20160428      DOH   NaN
# 4      3.0      NY  20553.0    19.0      2.0    1.0  20160406      NaN   NaN
#
#   entdepa entdepd  entdepu matflag  biryear   dtaddto gender  insnum airline  \
# 0       G       O      NaN       M   1955.0  07202016      F     NaN      JL
# 1       G       R      NaN       M   1990.0  10222016      M     NaN     *GA
# 2       G       O      NaN       M   1940.0  07052016      M     NaN      LH
# 3       G       O      NaN       M   1991.0  10272016      M     NaN      QR
# 4       Z       K      NaN       M   1997.0  07042016      F     NaN     NaN
#
#          admnum  fltno visatype
# 0  5.658267e+10  00782       WT
# 1  9.436200e+10  XBLNG       B2
# 2  5.578047e+10  00464       WT
# 3  9.478970e+10  00739       B2
# 4  4.232257e+10   LAND       WT

# %%
immi_df.shape
# Out:
# (1000, 29)

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.\
config("spark.jars.packages","saurfang:spark-sas7bdat:2.0.0-s_2.11")\
.enableHiveSupport().getOrCreate()
df_spark =spark.read.format('com.github.saurfang.sas.spark').load('../../data/18-83510-I94-Data-2016/i94_apr16_sub.sas7bdat')

# %%
df_spark.show()
# Out:
# +-----+------+------+------+------+-------+-------+-------+-------+-------+------+-------+-----+--------+--------+-----+-------+-------+-------+-------+-------+--------+------+------+-------+--------------+-----+--------+
# |cicid| i94yr|i94mon|i94cit|i94res|i94port|arrdate|i94mode|i94addr|depdate|i94bir|i94visa|count|dtadfile|visapost|occup|entdepa|entdepd|entdepu|matflag|biryear| dtaddto|gender|insnum|airline|        admnum|fltno|visatype|
# +-----+------+------+------+------+-------+-------+-------+-------+-------+------+-------+-----+--------+--------+-----+-------+-------+-------+-------+-------+--------+------+------+-------+--------------+-----+--------+
# |  6.0|2016.0|   4.0| 692.0| 692.0|    XXX|20573.0|   null|   null|   null|  37.0|    2.0|  1.0|    null|    null| null|      T|   null|      U|   null| 1979.0|10282016|  null|  null|   null| 1.897628485E9| null|      B2|
# |  7.0|2016.0|   4.0| 254.0| 276.0|    ATL|20551.0|    1.0|     AL|   null|  25.0|    3.0|  1.0|20130811|     SEO| null|      G|   null|      Y|   null| 1991.0|     D/S|     M|  null|   null|  3.73679633E9|00296|      F1|
# | 15.0|2016.0|   4.0| 101.0| 101.0|    WAS|20545.0|    1.0|     MI|20691.0|  55.0|    2.0|  1.0|20160401|    null| null|      T|      O|   null|      M| 1961.0|09302016|     M|  null|     OS|  6.66643185E8|   93|      B2|
# | 16.0|2016.0|   4.0| 101.0| 101.0|    NYC|20545.0|    1.0|     MA|20567.0|  28.0|    2.0|  1.0|20160401|    null| null|      O|      O|   null|      M| 1988.0|09302016|  null|  null|     AA|9.246846133E10|00199|      B2|
# | 17.0|2016.0|   4.0| 101.0| 101.0|    NYC|20545.0|    1.0|     MA|20567.0|   4.0|    2.0|  1.0|20160401|    null| null|      O|      O|   null|      M| 2012.0|09302016|  null|  null|     AA|9.246846313E10|00199|      B2|
# | 18.0|2016.0|   4.0| 101.0| 101.0|    NYC|20545.0|    1.0|     MI|20555.0|  57.0|    1.0|  1.0|20160401|    null| null|      O|      O|   null|      M| 1959.0|09302016|  null|  null|     AZ|9.247103803E10|00602|      B1|
# | 19.0|2016.0|   4.0| 101.0| 101.0|    NYC|20545.0|    1.0|     NJ|20558.0|  63.0|    2.0|  1.0|20160401|    null| null|      O|      K|   null|      M| 1953.0|09302016|  null|  null|     AZ|9.247139923E10|00602|      B2|
# | 20.0|2016.0|   4.0| 101.0| 101.0|    NYC|20545.0|    1.0|     NJ|20558.0|  57.0|    2.0|  1.0|20160401|    null| null|      O|      K|   null|      M| 1959.0|09302016|  null|  null|     AZ|9.247161383E10|00602|      B2|
# | 21.0|2016.0|   4.0| 101.0| 101.0|    NYC|20545.0|    1.0|     NY|20553.0|  46.0|    2.0|  1.0|20160401|    null| null|      O|      O|   null|      M| 1970.0|09302016|  null|  null|     AZ|9.247079603E10|00602|      B2|
# | 22.0|2016.0|   4.0| 101.0| 101.0|    NYC|20545.0|    1.0|     NY|20562.0|  48.0|    1.0|  1.0|20160401|    null| null|      O|      O|   null|      M| 1968.0|09302016|  null|  null|     AZ|9.247848973E10|00608|      B1|
# | 23.0|2016.0|   4.0| 101.0| 101.0|    NYC|20545.0|    1.0|     NY|20671.0|  52.0|    2.0|  1.0|20160401|    null| null|      O|      O|   null|      M| 1964.0|09302016|  null|  null|     TK|9.250139443E10|00001|      B2|
# | 24.0|2016.0|   4.0| 101.0| 101.0|    TOR|20545.0|    1.0|     MO|20554.0|  33.0|    2.0|  1.0|20160401|    null| null|      O|      O|   null|      M| 1983.0|09302016|  null|  null|     MQ|9.249090503E10|03348|      B2|
# | 27.0|2016.0|   4.0| 101.0| 101.0|    BOS|20545.0|    1.0|     MA|20549.0|  58.0|    1.0|  1.0|20160401|     TIA| null|      G|      O|   null|      M| 1958.0|04062016|     M|  null|     LH|9.247876383E10|00422|      B1|
# | 28.0|2016.0|   4.0| 101.0| 101.0|    ATL|20545.0|    1.0|     MA|20549.0|  56.0|    1.0|  1.0|20160401|     TIA| null|      G|      O|   null|      M| 1960.0|04062016|     F|  null|     LH|9.247890033E10|00422|      B1|
# | 29.0|2016.0|   4.0| 101.0| 101.0|    ATL|20545.0|    1.0|     MA|20561.0|  62.0|    2.0|  1.0|20160401|     TIA| null|      G|      O|   null|      M| 1954.0|09302016|     M|  null|     AZ|9.250378143E10|00614|      B2|
# | 30.0|2016.0|   4.0| 101.0| 101.0|    ATL|20545.0|    1.0|     NJ|20578.0|  49.0|    2.0|  1.0|20160401|     TIA| null|      G|      O|   null|      M| 1967.0|09302016|     M|  null|     OS|9.247020943E10|00089|      B2|
# | 31.0|2016.0|   4.0| 101.0| 101.0|    ATL|20545.0|    1.0|     NY|20611.0|  43.0|    2.0|  1.0|20160401|     TIA| null|      G|      O|   null|      M| 1973.0|09302016|     M|  null|     OS|9.247128923E10|00089|      B2|
# | 33.0|2016.0|   4.0| 101.0| 101.0|    HOU|20545.0|    1.0|     TX|20554.0|  53.0|    2.0|  1.0|20160401|     TIA| null|      G|      O|   null|      M| 1963.0|09302016|     F|  null|     TK|9.250930163E10|00033|      B2|
# | 34.0|2016.0|   4.0| 101.0| 101.0|    NYC|20545.0|    1.0|     CT|   null|  48.0|    2.0|  1.0|20160401|     TIA| null|      G|   null|   null|   null| 1968.0|09302016|     M|  null|     AZ|9.247042023E10|00602|      B2|
# | 35.0|2016.0|   4.0| 101.0| 101.0|    NYC|20545.0|    1.0|     CT|   null|  74.0|    2.0|  1.0|20160401|     TIA| null|      T|   null|   null|   null| 1942.0|09302016|     F|  null|     TK|  6.69712185E8|    1|      B2|
# +-----+------+------+------+------+-------+-------+-------+-------+-------+------+-------+-----+--------+--------+-----+-------+-------+-------+-------+-------+--------+------+------+-------+--------------+-----+--------+
# only showing top 20 rows

# %%
#write to parquet
df_spark.write.parquet("sas_data")
df_spark=spark.read.parquet("sas_data")

# %% [markdown]
# ### Step 2: Explore and Assess the Data
# #### Explore the Data
# Identify data quality issues, like missing values, duplicate data, etc.
#
# #### Cleaning Steps
# Document steps necessary to clean the data

# %%
# Performing cleaning tasks here

# %% [markdown]
# ### Step 3: Define the Data Model
# #### 3.1 Conceptual Data Model
# Map out the conceptual data model and explain why you chose that model
#
# #### 3.2 Mapping Out Data Pipelines
# List the steps necessary to pipeline the data into the chosen data model

# %% [markdown]
# ### Step 4: Run Pipelines to Model the Data
# #### 4.1 Create the data model
# Build the data pipelines to create the data model.

# %%
# Write code here

# %% [markdown]
# #### 4.2 Data Quality Checks
# Explain the data quality checks you'll perform to ensure the pipeline ran as expected. These could include:
#  * Integrity constraints on the relational database (e.g., unique key, data type, etc.)
#  * Unit tests for the scripts to ensure they are doing the right thing
#  * Source/Count checks to ensure completeness
#
# Run Quality Checks

# %%
# Perform quality checks here

# %% [markdown]
# #### 4.3 Data dictionary
# Create a data dictionary for your data model. For each field, provide a brief description of what the data is and where it came from. You can include the data dictionary in the notebook or in a separate file.

# %% [markdown]
# #### Step 5: Complete Project Write Up
# * Clearly state the rationale for the choice of tools and technologies for the project.
# * Propose how often the data should be updated and why.
# * Write a description of how you would approach the problem differently under the following scenarios:
#  * The data was increased by 100x.
#  * The data populates a dashboard that must be updated on a daily basis by 7am every day.
#  * The database needed to be accessed by 100+ people.

# %%
# !pip install datapackage
# Out:
# Collecting datapackage
#   Downloading https://files.pythonhosted.org/packages/08/ff/85c2e70640770c169f2ab4a53dfa8f86fa73bcbfe071a1d477f7c0be7a1d/datapackage-1.13.0-py2.py3-none-any.whl (84kB)
#     100% |████████████████████████████████| 92kB 3.5MB/s ta 0:00:011
# Collecting tableschema>=1.12.1 (from datapackage)
#   Downloading https://files.pythonhosted.org/packages/8a/e3/c4d978d27185db74d2c868779931d002d37abe77ab8774b68ff93bbb9a0d/tableschema-1.15.3-py2.py3-none-any.whl (67kB)
#     100% |████████████████████████████████| 71kB 7.9MB/s ta 0:00:011
# Requirement already satisfied: click>=6.7 in /opt/conda/lib/python3.6/site-packages (from datapackage) (6.7)
# Requirement already satisfied: six>=1.10 in /opt/conda/lib/python3.6/site-packages (from datapackage) (1.11.0)
# Requirement already satisfied: jsonschema>=2.5 in /opt/conda/lib/python3.6/site-packages (from datapackage) (2.6.0)
# Collecting unicodecsv>=0.14 (from datapackage)
#   Downloading https://files.pythonhosted.org/packages/6f/a4/691ab63b17505a26096608cc309960b5a6bdf39e4ba1a793d5f9b1a53270/unicodecsv-0.14.1.tar.gz
# Collecting jsonpointer>=1.10 (from datapackage)
#   Downloading https://files.pythonhosted.org/packages/18/b0/a80d29577c08eea401659254dfaed87f1af45272899e1812d7e01b679bc5/jsonpointer-2.0-py2.py3-none-any.whl
# Requirement already satisfied: requests>=2.8 in /opt/conda/lib/python3.6/site-packages (from datapackage) (2.18.4)
# Collecting tabulator>=1.29 (from datapackage)
#   Downloading https://files.pythonhosted.org/packages/15/70/657cc89a1d27322ee7710aa671ffcd599367945b501e2436d13586d62c14/tabulator-1.38.2-py2.py3-none-any.whl (66kB)
#     100% |████████████████████████████████| 71kB 10.4MB/s ta 0:00:01
# Requirement already satisfied: chardet>=3.0 in /opt/conda/lib/python3.6/site-packages (from datapackage) (3.0.4)
# Collecting isodate>=0.5.4 (from tableschema>=1.12.1->datapackage)
#   Downloading https://files.pythonhosted.org/packages/9b/9f/b36f7774ff5ea8e428fdcfc4bb332c39ee5b9362ddd3d40d9516a55221b2/isodate-0.6.0-py2.py3-none-any.whl (45kB)
#     100% |████████████████████████████████| 51kB 12.8MB/s ta 0:00:01
# Requirement already satisfied: python-dateutil>=2.4 in /opt/conda/lib/python3.6/site-packages (from tableschema>=1.12.1->datapackage) (2.6.1)
# Collecting rfc3986>=1.1.0 (from tableschema>=1.12.1->datapackage)
#   Downloading https://files.pythonhosted.org/packages/78/be/7b8b99fd74ff5684225f50dd0e865393d2265656ef3b4ba9eaaaffe622b8/rfc3986-1.4.0-py2.py3-none-any.whl
# Requirement already satisfied: idna<2.7,>=2.5 in /opt/conda/lib/python3.6/site-packages (from requests>=2.8->datapackage) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /opt/conda/lib/python3.6/site-packages (from requests>=2.8->datapackage) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.6/site-packages (from requests>=2.8->datapackage) (2019.11.28)
# Collecting linear-tsv>=1.0 (from tabulator>=1.29->datapackage)
#   Downloading https://files.pythonhosted.org/packages/82/e5/03207a0f11e1d60df85b97b61704ed701b725a7c2feaf83f7bfbd0c2d83e/linear-tsv-1.1.0.tar.gz
# Requirement already satisfied: boto3>=1.9 in /opt/conda/lib/python3.6/site-packages (from tabulator>=1.29->datapackage) (1.9.7)
# Collecting jsonlines>=1.1 (from tabulator>=1.29->datapackage)
#   Downloading https://files.pythonhosted.org/packages/4f/9a/ab96291470e305504aa4b7a2e0ec132e930da89eb3ca7a82fbe03167c131/jsonlines-1.2.0-py2.py3-none-any.whl
# Requirement already satisfied: xlrd>=1.0 in /opt/conda/lib/python3.6/site-packages (from tabulator>=1.29->datapackage) (1.1.0)
# Requirement already satisfied: sqlalchemy>=0.9.6 in /opt/conda/lib/python3.6/site-packages (from tabulator>=1.29->datapackage) (1.1.13)
# Collecting openpyxl>=2.6 (from tabulator>=1.29->datapackage)
#   Downloading https://files.pythonhosted.org/packages/95/8c/83563c60489954e5b80f9e2596b93a68e1ac4e4a730deb1aae632066d704/openpyxl-3.0.3.tar.gz (172kB)
#     100% |████████████████████████████████| 174kB 7.9MB/s ta 0:00:01
# Collecting ijson>=2.5 (from tabulator>=1.29->datapackage)
#   Downloading https://files.pythonhosted.org/packages/21/dd/a71708dc0687aa9682be5497bc93176140a33611d3f3c923bc7910d070a1/ijson-3.0.1-cp36-cp36m-manylinux1_x86_64.whl (95kB)
#     100% |████████████████████████████████| 102kB 13.0MB/s a 0:00:01
# Requirement already satisfied: botocore<1.13.0,>=1.12.7 in /opt/conda/lib/python3.6/site-packages (from boto3>=1.9->tabulator>=1.29->datapackage) (1.12.7)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /opt/conda/lib/python3.6/site-packages (from boto3>=1.9->tabulator>=1.29->datapackage) (0.9.3)
# Requirement already satisfied: s3transfer<0.2.0,>=0.1.10 in /opt/conda/lib/python3.6/site-packages (from boto3>=1.9->tabulator>=1.29->datapackage) (0.1.13)
# Requirement already satisfied: jdcal in /opt/conda/lib/python3.6/site-packages (from openpyxl>=2.6->tabulator>=1.29->datapackage) (1.3)
# Requirement already satisfied: et_xmlfile in /opt/conda/lib/python3.6/site-packages (from openpyxl>=2.6->tabulator>=1.29->datapackage) (1.0.1)
# Requirement already satisfied: docutils>=0.10 in /opt/conda/lib/python3.6/site-packages (from botocore<1.13.0,>=1.12.7->boto3>=1.9->tabulator>=1.29->datapackage) (0.14)
# Building wheels for collected packages: unicodecsv, linear-tsv, openpyxl
#   Running setup.py bdist_wheel for unicodecsv ... done
#   Stored in directory: /root/.cache/pip/wheels/a6/09/e9/e800279c98a0a8c94543f3de6c8a562f60e51363ed26e71283
#   Running setup.py bdist_wheel for linear-tsv ... done
#   Stored in directory: /root/.cache/pip/wheels/3f/8a/cb/38917fd1ef4356b9870ace7331b83417dc594bf2c029bd991f
#   Running setup.py bdist_wheel for openpyxl ... done
#   Stored in directory: /root/.cache/pip/wheels/b5/85/ca/e768ac132e57e75e645a151f8badac71cc0089e7225dddf76b
# Successfully built unicodecsv linear-tsv openpyxl
# Installing collected packages: isodate, unicodecsv, rfc3986, linear-tsv, jsonlines, openpyxl, ijson, tabulator, tableschema, jsonpointer, datapackage
#   Found existing installation: openpyxl 2.5.0b1
#     Uninstalling openpyxl-2.5.0b1:
#       Successfully uninstalled openpyxl-2.5.0b1
# Successfully installed datapackage-1.13.0 ijson-3.0.1 isodate-0.6.0 jsonlines-1.2.0 jsonpointer-2.0 linear-tsv-1.1.0 openpyxl-3.0.3 rfc3986-1.4.0 tableschema-1.15.3 tabulator-1.38.2 unicodecsv-0.14.1

# %%
from datapackage import Package

package = Package('https://datahub.io/core/covid-19/datapackage.json')

# print list of all resources:
print(package.resource_names)

# print processed tabular data (if exists any)
for resource in package.resources:
    if resource.descriptor['datahub']['type'] == 'derived/csv':
        print(resource.read())
# Out:
# ['validation_report', 'time-series-19-covid-combined_csv', 'key-countries-pivoted_csv', 'countries-aggregated_csv', 'worldwide-aggregated_csv', 'us_confirmed_csv', 'us_deaths_csv', 'reference_csv', 'time-series-19-covid-combined_json', 'key-countries-pivoted_json', 'countries-aggregated_json', 'worldwide-aggregated_json', 'us_confirmed_json', 'us_deaths_json', 'reference_json', 'covid-19_zip', 'time-series-19-covid-combined_csv_preview', 'countries-aggregated_csv_preview', 'us_confirmed_csv_preview', 'us_deaths_csv_preview', 'reference_csv_preview', 'time-series-19-covid-combined', 'key-countries-pivoted', 'countries-aggregated', 'worldwide-aggregated', 'us_confirmed', 'us_deaths', 'reference']
# [[datetime.date(2020, 1, 22), 'Afghanistan', None, Decimal('33.0'), Decimal('65.0'), 0, 0, 0], [datetime.date(2020, 1, 23), 'Afghanistan', None, Decimal('33.0'), Decimal('65.0'), 0, 0, 0], [datetime.date(2020, 1, 24), 'Afghanistan', None, Decimal('33.0'), Decimal('65.0'), 0, 0, 0], [datetime.date(2020, 1, 25), 'Afghanistan', None, Decimal('33.0'), Decimal('65.0'), 0, 0, 0], [datetime.date(2020, 1, 26), 'Afghanistan', None, Decimal('33.0'), Decimal('65.0'), 0, 0, 0], [datetime.date(2020, 1, 27), 'Afghanistan', None, Decimal('33.0'), Decimal('65.0'), 0, 0, 0], [datetime.date(2020, 1, 28), 'Afghanistan', None, Decimal('33.0'), Decimal('65.0'), 0, 0, 0], [datetime.date(2020, 1, 29), 'Afghanistan', None, Decimal('33.0'), Decimal('65.0'), 0, 0, 0], [datetime.date(2020, 1, 30), 'Afghanistan', None, Decimal('33.0'), Decimal('65.0'), 0, 0, 0], [datetime.date(2020, 1, 31), 'Afghanistan', None, Decimal('33.0'), Decimal('65.0'), 0, 0, 0], [datetime.date(2020, 2, 1), 'Afghanistan', None, Decimal('33.0'), Decimal('65.0'), 0, 0, 0], [datetime.date(2020, 2, 2), 'Afghanistan', None, Decimal('33.0'), Decimal('65.0'), 0, 0, 0], [datetime.date(2020, 2, 3), 'Afghanistan', None, Decimal('33.0'), Decimal('65.0'), 0, 0, 0], [datetime.date(2020, 2, 4), 'Afghanistan', None, Decimal('33.0'), Decimal('65.0'), 0, 0, 0], [datetime.date(2020, 2, 5), 'Afghanistan', None, Decimal('33.0'), Decimal('65.0'), 0, 0, 0], [datetime.date(2020, 2, 6), 'Afghanistan', None, Decimal('33.0'), Decimal('65.0'), 0, 0, 0], [datetime.date(2020, 2, 7), 'Afghanistan', None, Decimal('33.0'), Decimal('65.0'), 0, 0, 0], [datetime.date(2020, 2, 8), 'Afghanistan', None, Decimal('33.0'), Decimal('65.0'), 0, 0, 0], [datetime.date(2020, 2, 9), 'Afghanistan', None, Decimal('33.0'), Decimal('65.0'), 0, 0, 0], [datetime.date(2020, 2, 10), 'Afghanistan', None, Decimal('33.0'), Decimal('65.0'), 0, 0, 0], [datetime.date(2020, 2, 11), 'Afghanistan', None, Decimal('33.0'), Decimal('65.0'), 0, 0, 0], [datetime.date(2020, 2, 12), 'Afghanistan', None, Decimal('33.0'), Decimal('65.0'), 0, 0, 0], [datetime.date(2020, 2, 13), 'Afghanistan', None, Decimal('33.0'), Decimal('65.0'), 0, 0, 0], [datetime.date(2020, 2, 14), 'Afghanistan', None, Decimal('33.0'), Decimal('65.0'), 0, 0, 0], [datetime.date(2020, 2, 15), 'Afghanistan', None, Decimal('33.0'), Decimal('65.0'), 0, 0, 0], [datetime.date(2020, 2, 16), 'Afghanistan', None, Decimal('33.0'), Decimal('65.0'), 0, 0, 0], [datetime.date(2020, 2, 17), 'Afghanistan', None, Decimal('33.0'), Decimal('65.0'), 0, 0, 0], [datetime.date(2020, 2, 18), 'Afghanistan', None, Decimal('33.0'), Decimal('65.0'), 0, 0, 0], [datetime.date(2020, 2, 19), 'Afghanistan', None, Decimal('33.0'), Decimal('65.0'), 0, 0, 0], [datetime.date(2020, 2, 20), 'Afghanistan', None, Decimal('33.0'), Decimal('65.0'), 0, 0, 0], [datetime.date(2020, 2, 21), 'Afghanistan', None, Decimal('33.0'), Decimal('65.0'), 0, 0, 0], [datetime.date(2020, 2, 22), 'Afghanistan', None, Decimal('33.0'), Decimal('65.0'), 0, 0, 0], [datetime.date(2020, 2, 23), 'Afghanistan', None, Decimal('33.0'), Decimal('65.0'), 0, 0, 0], [datetime.date(2020, 2, 24), 'Afghanistan', None, Decimal('33.0'), Decimal('65.0'), 1, 0, 0], [datetime.date(2020, 2, 25), 'Afghanistan', None, Decimal('33.0'), Decimal('65.0'), 1, 0, 0], [datetime.date(2020, 2, 26), 'Afghanistan', None, Decimal('33.0'), Decimal('65.0'), 1, 0, 0], [datetime.date(2020, 2, 27), 'Afghanistan', None, Decimal('33.0'), Decimal('65.0'), 1, 0, 0], [datetime.date(2020, 2, 28), 'Afghanistan', None, Decimal('33.0'), Decimal('65.0'), 1, 0, 0], [datetime.date(2020, 2, 29), 'Afghanistan', None, Decimal('33.0'), Decimal('65.0'), 1, 0, 0], [datetime.date(2020, 3, 1), 'Afghanistan', None, Decimal('33.0'), Decimal('65.0'), 1, 0, 0], [datetime.date(2020, 3, 2), 'Afghanistan', None, Decimal('33.0'), Decimal('65.0'), 1, 0, 0], [datetime.date(2020, 3, 3), 'Afghanistan', None, Decimal('33.0'), Decimal('65.0'), 1, 0, 0], [datetime.date(2020, 3, 4), 'Afghanistan', None, Decimal('33.0' ...
# [[datetime.date(2020, 1, 22), 548, 1, 0, 0, 0, 0, 0, 0], [datetime.date(2020, 1, 23), 643, 1, 0, 0, 0, 0, 0, 0], [datetime.date(2020, 1, 24), 920, 2, 0, 0, 2, 0, 0, 0], [datetime.date(2020, 1, 25), 1406, 2, 0, 0, 3, 0, 0, 0], [datetime.date(2020, 1, 26), 2075, 5, 0, 0, 3, 0, 0, 0], [datetime.date(2020, 1, 27), 2877, 5, 
222, 2922], [datetime.date(2020, 3, 5), 80537, 217, 116, 3858, 380, 482, 259, 3513], [datetime.date(2020, 3, 6), 80690, 262, 164, 4636, 656, 670, 400, 4747], [datetime.date(2020, 3, 7), 80770, 402, 207, 5883, 959, 799, 500, 5823], [datetime.date(2020, 3, 8), 80823, 518, 274, 7375, 1136, 1040, 673, 6566], [datetime.date(2020, 3, 9), 80860, 583, 322, 9172, 1219, 1176, 1073, 7161], [datetime.date(2020, 3, 10), 80887, 959, 384, 10149, 1794, 1457, 1695, 8042], [datetime.date(2020, 3, 11), 80921, 1281, 459, 12462, 2293, 1908, 2277, 9000], [datetime.date(2020, 3, 12), 80932, 1663, 459, 12462, 2293, 2078, 2277, 10075], [datetime.date(2020, 3, 13), 80945, 2179, 802, 17660, 3681, 3675, 5232, 11364], [datetime.date(2020, 3, 14), 80977, 2727, 1144, 21157, 4496, 4585, 6391, 12729], [datetime.date(2020, 3, 15), 81003, 3499, 1145, 24747, 4532, 5795, 7798, 13938], [datetime.date(2020, 3, 16), 81033, 4632, 1551, 27980, 6683, 7272, 9942, 14991], [datetime.date(2020, 3, 17), 81058, 6421, 1960, 31506, 7715, 9257, 11748, 16169], [datetime.date(2020, 3, 18), 81102, 7783, 2642, 35713, 9124, 12327, 13910, 17361], [datetime.date(2020, 3, 19), 81156, 13747, 2716, 41035, 10970, 15320, 17963, 18407], [datetime.date(2020, 3, 20), 81250, 19273, 4014, 47021, 12758, 19848, 20410, 19644], [datetime.date(2020, 3, 21), 81305, 25600, 5067, 53578, 14463, 22213, 25374, 20610], [dateti ...
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [[4, 'AF', 'AFG', 4, None, None, None, 'Afghanistan', Decimal('33.93911'), Decimal('67.709953'), 'Afghanistan', 38928341], [8, 'AL', 'ALB', 8, None, None, None, 'Albania', Decimal('41.1533'), Decimal('20.1683'), 'Albania', 2877800], [12, 'DZ', 'DZA', 12, None, None, None, 'Algeria', Decimal('28.0339'), Decimal('1.6596'), 'Algeria', 43851043], [20, 'AD', 'AND', 20, None, None, None, 'Andorra', Decimal('42.5063'), Decimal('1.5218'), 'Andorra', 77265], [24, 'AO', 'AGO', 24, None, None, None, 'Angola', Decimal('-11.2027'), Decimal('17.8739'), 'Angola', 32866268], [28, 'AG', 'ATG', 28, None, None, None, 'Antigua and Barbuda', Decimal('17.0608'), Decimal('-61.7964'), 'Antigua and Barbuda', 97928], [32, 'AR', 'ARG', 32, None, None, None, 'Argentina', Decimal('-38.4161'), Decimal('-63.6167'), 'Argentina', 45195777], [51, 'AM', 'ARM', 51, None, None, None, 'Armenia', Decimal('40.0691'), Decimal('45.0382'), 'Armenia', 2963234], [40, 'AT', 'AUT', 40, None, None, None, 'Austria', Decimal('47.5162'), Decimal('14.5501'), 'Austria', 9006400], [31, 'AZ', 'AZE', 31, None, None, None, 'Azerbaijan', Decimal('40.1431'), Decimal('47.5769'), 'Azerbaijan', 10139175], [44, 'BS', 'BHS', 44, None, None, None, 'Bahamas', Decimal('25.025885'), Decimal('-78.035889'), 'Bahamas', 393248], [48, 'BH', 'BHR', 48, None, None, None, 'Bahrain', Decimal('26.0275'), Decimal('50.55'), 'Bahrain', 1701583], [50, 'BD', 'BGD', 50, None, None, None, 'Bangladesh', Decimal('23.685'), Decimal('90.3563'), 'Bangladesh', 164689383], [52, 'BB', 'BRB', 52, None, None, None, 'Barbados', Decimal('13.1939'), Decimal('-59.5432'), 'Barbados', 287371], [112, 'BY', 'BLR', 112, None, None, None, 'Belarus', Decimal('53.7098'), Decimal('27.9534'), 'Belarus', 9449321], [56, 'BE', 'BEL', 56, None, None, None, 'Belgium', Decimal('50.8333'), Decimal('4.469936'), 'Belgium', 11589616], [84, 'BZ', 'BLZ', 84, None, None, None, 'Belize', Decimal('17.1899'), Decimal('-88.4976'), 'Belize', 397621], [204, 'BJ', 'BEN', 204, None, None, None, 'Benin', Decimal('9.3077'), Decimal('2.3158'), 'Benin', 12123198], [64, 'BT', 'BTN', 64, None, None, None, 'Bhutan', Decimal('27.5142'), Decimal('90.4336'), 'Bhutan', 771612], [68, 'BO', 'BOL', 68, None, None, None, 'Bolivia', Decimal('-16.2902'), Decimal('-63.5887'), 'Bolivia', 11673029], [70, 'BA', 'BIH', 70, None, None, None, 'Bosnia and Herzegovina', Decimal('43.9159'), Decimal('17.6791'), 'Bosnia and Herzegovina', 3280815], [72, 'BW', 'BWA', 72, None, None, None, 'Botswana', Decimal('-22.3285'), Decimal('24.6849'), 'Botswana', 2351625], [76, 'BR', 'BRA', 76, None, None, None, 'Brazil', Decimal('-14.235'), Decimal('-51.9253'), 'Brazil', 212559409], [96, 'BN', 'BRN', 96, None, None, None, 'Brunei', Decimal('4.5353'), Decimal('114.7277'), 'Brunei', 437483], [100, 'BG', 'BGR', 100, None, None, None, 'Bulgaria', Decimal('42.7339'), Decimal('25.4858'), 'Bulgaria', 6948445], [854, 'BF', 'BFA', 854, None, None, None, 'Burkina Faso', Decimal('12.2383'), Decimal('-1.5616'), 'Burkina Faso', 20903278], [104, 'MM', 'MMR', 104, None, None, None, 'Burma', Decimal('21.9162'), Decimal('95.956'), 'Burma', 54409794], [108, 'BI', 'BDI', 108, None, None, None, 'Burundi', Decimal('-3.3731'), Decimal('29.9189'), 'Burundi', 11890781], [132, 'CV', 'CPV', 132, None, None, None, 'Cabo Verde', Decimal('16.5388'), Decimal('-23.0418'), 'Cabo Verde', 555988], [116, 'KH', 'KHM', 116, None, None, None, 'Cambodia', Decimal('11.55'), Decimal('104.9167'), 'Cambodia', 16718971], [120, 'CM', 'CMR', 120, None, None, None, 'Cameroon', Decimal('3.848'), Decimal('11.5021'), 'Cameroon', 26545864], [140, 'CF', 'CAF', 140, None, None, None, 'Central African Republic', Decimal('6.6111'), Decimal('20.9394'), 'Central African Republic', 4829764], [148, 'TD', 'TCD', 148, None, None, None, 'Chad', Decimal('15.4542'), Decimal('18.7322'), 'Chad', 16425859], [152, 'CL', 'CHL', 152, None, None, None, 'Chile', Decimal('-35.6751'), Decimal('-71.543'), 'Chile', 19116209], [170, 'CO', 'COL', 170, None, None, None, ' ...
